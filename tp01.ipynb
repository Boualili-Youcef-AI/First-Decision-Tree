# %%
# %load_ext autoreload
# %autoreload 2
import data_arbres as da
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Data

# %%
# Chargez les données
data = da.load_data("tp_donnees.csv")
data
# Out:
# [x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 42.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.55, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 13.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 2.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 16.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 35.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 1.0}, y: 1,
#  x: {'Classe': 3.0, 'Nationalite': 2.0, 'Age': 16.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.65, 'Genre': 1.0}, y: 1,
# ...

# %%
proba = da.proba_empirique(data)
proba
# Out:
# {0: 0.5913875598086125, 1: 0.40861244019138754}

# %%
data[0].x["Age"]
# Out:
# 42.0

# %%
age = da.question_inf(data[0],"Age", 24)
age
# Out:
# False

# %%
print(data)
# Out:
# [x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 42.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.55, 'Genre': 0.0}, y: 0, x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 13.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 2.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0, x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 16.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0, x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 35.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 1.0}, y: 1, x: {'Classe': 3.0, 'Nationalite': 2.0, 'Age': 16.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.65, 'Genre': 1.0}, y: 1, x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 25.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.65, '
# ...

# %%
[d1, d2] = da.split(data, ("Age", 12))
d2
# Out:
# [x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 42.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.55, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 13.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 2.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 16.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 0.0}, y: 0,
#  x: {'Classe': 3.0, 'Nationalite': 0.0, 'Age': 35.0, 'Nombre de freres/soeurs': 1.0, 'Nombre d enfants/parents a bord': 1.0, 'Prix du ticket': 20.25, 'Genre': 1.0}, y: 1,
#  x: {'Classe': 3.0, 'Nationalite': 2.0, 'Age': 16.0, 'Nombre de freres/soeurs': 0.0, 'Nombre d enfants/parents a bord': 0.0, 'Prix du ticket': 7.65, 'Genre': 1.0}, y: 1,
# ...

# %%
list = da.list_separ_attributs(data, "Age")
print(list)
# Out:
# [['Age', 0.25], ['Age', 0.375], ['Age', 0.5417], ['Age', 0.70835], ['Age', 0.79165], ['Age', 0.875], ['Age', 0.95835], ['Age', 1.5], ['Age', 2.5], ['Age', 3.5], ['Age', 4.5], ['Age', 5.5], ['Age', 6.5], ['Age', 7.5], ['Age', 8.5], ['Age', 9.5], ['Age', 10.5], ['Age', 11.25], ['Age', 11.75], ['Age', 12.5], ['Age', 13.5], ['Age', 14.25], ['Age', 14.75], ['Age', 15.5], ['Age', 16.5], ['Age', 17.5], ['Age', 18.25], ['Age', 18.75], ['Age', 19.5], ['Age', 20.25], ['Age', 20.75], ['Age', 21.5], ['Age', 22.25], ['Age', 22.75], ['Age', 23.25], ['Age', 23.75], ['Age', 24.25], ['Age', 24.75], ['Age', 25.5], ['Age', 26.25], ['Age', 26.75], ['Age', 27.5], ['Age', 28.25], ['Age', 28.75], ['Age', 29.5], ['Age', 30.25], ['Age', 30.75], ['Age', 31.5], ['Age', 32.25], ['Age', 32.75], ['Age', 33.5], ['Age', 34.25], ['Age', 34.75], ['Age', 35.5], ['Age', 36.25], ['Age', 36.75], ['Age', 37.5], ['Age', 38.25], ['Age', 38.75], ['Age', 39.5], ['Age', 40.25], ['Age', 40.75], ['Age', 41.5], ['Age', 42.5], ['A
# ...

# %%
test = da.liste_questions(data)
test
# Out:
# [['Classe', 1.5],
#  ['Classe', 2.5],
#  ['Nationalite', 0.5],
#  ['Nationalite', 1.5],
#  ['Age', 0.25],
#  ['Age', 0.375],
#  ['Age', 0.5417],
#  ['Age', 0.70835],
#  ['Age', 0.79165],
#  ['Age', 0.875],
#  ['Age', 0.95835],
#  ['Age', 1.5],
#  ['Age', 2.5],
#  ['Age', 3.5],
#  ['Age', 4.5],
#  ['Age', 5.5],
#  ['Age', 6.5],
#  ['Age', 7.5],
#  ['Age', 8.5],
#  ['Age', 9.5],
#  ['Age', 10.5],
#  ['Age', 11.25],
#  ['Age', 11.75],
#  ['Age', 12.5],
#  ['Age', 13.5],
#  ['Age', 14.25],
#  ['Age', 14.75],
#  ['Age', 15.5],
#  ['Age', 16.5],
#  ['Age', 17.5],
#  ['Age', 18.25],
#  ['Age', 18.75],
#  ['Age', 19.5],
#  ['Age', 20.25],
#  ['Age', 20.75],
#  ['Age', 21.5],
#  ['Age', 22.25],
#  ['Age', 22.75],
#  ['Age', 23.25],
#  ['Age', 23.75],
#  ['Age', 24.25],
#  ['Age', 24.75],
#  ['Age', 25.5],
#  ['Age', 26.25],
#  ['Age', 26.75],
#  ['Age', 27.5],
#  ['Age', 28.25],
#  ['Age', 28.75],
#  ['Age', 29.5],
#  ['Age', 30.25],
#  ['Age', 30.75],
#  ['Age', 31.5],
#  ['Age', 32.25],
# ...

# %%
proba = da.entropie(data)
proba
# Out:
# 0.9757661302191036

# %%
gain = da.gain_entropie(data, ("Genre", 0.5))
gain
# Out:
# 0.2153838940211723

# %%
best_question = da.best_split(data)
